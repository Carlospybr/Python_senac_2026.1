# %% [markdown]
# #### 01

# %%
d1 = {}
d2 = dict()

telefones = {
                "Carlos": "1425-3245", 
                "Rosangela": "4434-6543",
                "Cristian": "4578-9876",
                "Julio": "6675-1013",
                "Roberto": "9563-2745",
                "Conceição": "1873-1865"

                                    }
print(telefones)
# Out:
# {'Carlos': '1425-3245', 'Rosangela': '4434-6543', 'Cristian': '4578-9876', 'Julio': '6675-1013', 'Roberto': '9563-2745', 'Conceição': '1873-1865'}

# %%
telefones["Kangu"]="4563-2522"
print(telefones)
# Out:
# {'Carlos': '1425-3245', 'Rosangela': '4434-6543', 'Cristian': '4578-9876', 'Julio': '6675-1013', 'Roberto': '9563-2745', 'Conceição': '1873-1865', 'Kangu': '4563-2522'}

# %%
d3 = dict(Nome= "Carlos", Idade= "25")
print(d3)

listas_tuplas= [("a", '1'), ("b", '2')]

d4 = dict(listas_tuplas)

print(d4)
# Out:
# {'Nome': 'Carlos', 'Idade': '25'}
# {'a': '1', 'b': '2'}

# %% [markdown]
# #### 02

# %%
chaves = {"nome", "dt_nascimento", "cep", "logradouro", "bairro", "cidade", "estado"}
valor_padrao = "N/A"
usuario = dict.fromkeys(chaves, valor_padrao)
print(usuario)
# Out:
# {'cep': 'N/A', 'cidade': 'N/A', 'estado': 'N/A', 'nome': 'N/A', 'logradouro': 'N/A', 'bairro': 'N/A', 'dt_nascimento': 'N/A'}

# %%
usuario["nome"]="Carlos"

# %%
usuario["nome"]
usuario["dt_nascimento"]="25/09/2003"
usuario["cep"]="257481955"
usuario["logradouro"]="Rua das Flores"
usuario["bairro"]="Cuiaba"
usuario["cidade"]="Petropolis"
usuario["estado"]="RJ"

# %%
for chaves, valor in usuario.items():
    print(f'{chaves.capitalize():_<20}: {valor.capitalize()}')
# Out:
# Cep_________________: 257481955
# Cidade______________: Petropolis
# Estado______________: Rj
# Nome________________: Carlos
# Logradouro__________: Rua das flores
# Bairro______________: Cuiaba
# Dt_nascimento_______: 25/09/2003

# %%
clientes={}
clientes["123456"]=usuario
print(clientes)
# Out:
# {'123456': {'cep': '257481955', 'cidade': 'Petropolis', 'estado': 'RJ', 'nome': 'Carlos', 'logradouro': 'Rua das Flores', 'bairro': 'Cuiaba', 'dt_nascimento': '25/09/2003'}}
