# %%
def saudação():
    print('Olá, Mundo.')

# %%
def main():
    print('Saudações')

if __name__=="__main__":
    main()

# %% [markdown]
# #### Crie um programa Python que use a função main() para calcular e imprimir a soma de dois números fornecidos pelo usuário.

# %%
def main():
    num1=float(input('Insira o primeiro numero: '))
    num2=float(input('Insira o segundo numero: '))
    soma = num1 + num2
    print(f'A soma é {soma}')

if __name__ == "__main__":
    main()

# %% [markdown]
# #### Escreva um programa Python que use a função main() para chamar outras funções, como soma() e subtracao(), e exiba os resultados.

# %%
def soma1():    
    num1=float(input('Insira o primeiro numero: '))
    num2=float(input('Insira o segundo numero: '))
    soma = num1 + num2
    print(f'A soma é {soma}')

# %%
def subtracao():
    n1=float(input('Insira o primeiro numero: '))
    n2=float(input('Insira o segundo numero: '))
    sub= n1 - n2
    print('A subtração é', sub)

# %%
def main():
    soma1()
    subtracao()

if __name__ == "__main__":
    main()

# %% [markdown]
# #### Crie um programa Python que use a função main() para imprimir os números de 1 a 10.

# %%
def main():
    for i in range(1,11):
        print(i)

if __name__ == "__main__":
    main()

# %% [markdown]
# #### Escreva um programa Python que use a função main() para calcular o fatorial de um número fornecido pelo usuário.

# %%
def main(n):
    for i in range(1, n + 1)
    resultado *= i
    print('O fatorial de', n 'é', resultado)

# %%
# Versão Algorítmica (Raciocínio Lógico)

def main():

    contador = 0

    while True:
        try:
            numero = abs(int(input("Insira um Número:")))
            break
        except ValueError:
            print('Valor invalido! Tente novamente.')


    if numero == 0:
        return 1

    while numero > 0:
        numero = numero // 10
        contador = contador + 1

    return contador

if __name__ == '__main__':
    main()

# %%
print(main())
# Out:
# 3
