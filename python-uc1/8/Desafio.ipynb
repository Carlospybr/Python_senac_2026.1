# %% [markdown]
# # Criar funções

# %% [markdown]
# ## 8.1 Funções Simples

# %%
def soma (a, b):
    soma = (a + b)
    return soma

# %%
resultado=soma(15,12)
print(resultado)
# Out:
# 27

# %%
def potencia (numero, expoente):
    resultado = numero ** expoente
    return resultado

# %%
numero=2
expoente=8

print(potencia(numero,expoente))
# Out:
# 256

# %%
def soma_2 (n1,n2):
    soma = n1+n2
    print (soma)
soma_2 (12.4,15)
# Out:
# 27.4

# %%
resposta = soma_2 (12,50)
print(resposta)
# Out:
# 62
# None

# %%
def potencia (numero, expoente):
    resultado = numero ** expoente
    return resultado

# %%
numero = 2
expoente = 8
print(potencia(numero,expoente))
# Out:
# 256

# %%
n2=5
exp=4
resultado=potencia(n2,exp)
resultado2=potencia(exp,n2)

# %%
print(f'{resultado} <> {resultado2}')
# Out:
# 625 <> 1024
