# %% [markdown]
# # Aula 03 - Variáveis

# %% [markdown]
# ## Olá, Mundo!

# %% [markdown]
# ### Tipos de Variáveis

# %%
numero_inteiro=15
numero_real=15.2
texto="cinco"

# %%
print(type(numero_inteiro), type(numero_real),  type(texto))
# Out:
# <class 'int'> <class 'tuple'> <class 'str'>

# %%
numero_inteiro+numero_real
# Out:
# 30.2

# %%
numero_inteiro+texto
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[35], line 1
# ----> 1 numero_inteiro+texto
#
# TypeError: unsupported operand type(s) for +: 'int' and 'str'

# %%
texto*numero_inteiro
# Out:
# 'cincocincocincocincocincocincocincocincocincocincocincocincocincocincocinco'

# %%
texto2=texto+" "

# %%
print(texto), (texto2)
# Out:
# cinco
# (None, 'cinco ')

# %%
idade=int(input("Qual sua idade?"))

# %%
type(idade)
# Out:
# int
