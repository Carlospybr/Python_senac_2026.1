# %%
# Definindo uma classe chamada 'Carro'
class Carro:
    # Método construtor (__init__) para inicializar os atributos
    def __init__(self, marca, modelo, portas=4, ano=2026, cor="branca"):
        self.marca = marca      # Atributo
        self.modelo = modelo    # Atributo
        self.ano = ano          # Atributo
        self.cor = cor          # Atributo
        self.potencia=1.0
        self.cambio = "auto"    # Atributo
        self.qt_portas=portas    # Atributo
        self.dir_hidraulica=True
        self.tp_tracao=2
        self._cambio_automatico=False
        self._4p4=False
        self.__ligado = False     # Atributo com valor padrão


    # Método para ligar o carro
    def __ligar(self):
        if not self.__ligado:
            self.__ligado = True
            print(f"{self.marca} {self.modelo} está ligado.")
        else:
            print(f"{self.marca} {self.modelo} já está ligado.")

    # Método para desligar o carro
    def desligar(self):
        if self.__ligado:
            self.__ligado = False
            print(f"{self.marca} {self.modelo} está desligado.")
        else:
            print(f"{self.marca} {self.modelo} já está desligado.")

    # Método para exibir informações do carro
    def exibir_info(self):
        status = "ligado" if self.__ligado else "desligado"
        print(f"{self.marca} {self.modelo} ({self.ano}) está {status}.")

    def mudar_cor (self, cor):
        self.cor = cor
        return True

    def mudar_cambio (self, cambio):
        cambio = cambio.lower
        if cambio == "auto":
            self.cambio = "auto"
        elif cambio == "manual":
            self.cambio = "manual"
        else:
            return False
        return True

    def mudar_tracao (self):
        if self.tp_tracao == 2:
            self.tp_tracao = 4
        else:
            self.tp_tracao = 2
        return True

            
    def mudar_pot (self, pot="1.0"):
        try:
            v1_pot=float(pot)
            self.potencia = v1_pot
            return True
        except:
            return False



# Criando um objeto da classe Carro
meu_carro = Carro("Toyota", "Corolla")

# Usando métodos do objeto
meu_carro.exibir_info()  # Exibe as informações do carro
meu_carro._ligar()  # Liga o carro
meu_carro.exibir_info()  # Exibe as informações do carro novamente
meu_carro.desligar()  # Desliga o carro
meu_carro.exibir_info()  # Exibe as informações do carro novamente
# Out:
# Toyota Corolla (2026) está desligado.
# Toyota Corolla está ligado.
# Toyota Corolla (2026) está ligado.
# Toyota Corolla está desligado.
# Toyota Corolla (2026) está desligado.

# %%
meu_carro = Carro("Vw", "Gol", "2013","Vermelho", "Manual", "Dianteira", "2 Portas")
meu_carro2 = Carro("Fiat", "Palio","2020", "Branco", "Manual", "Dianteira", "4 Portas")

# %%
meu_carro.mudar_pot(3.0)
# Out:
# True
