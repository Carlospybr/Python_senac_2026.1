# %% [markdown]
# #### 01

# %%
import random

def criar_matriz(qt_linhas=4, qt_colunas=4):

    matriz = []

    for linha in range(qt_linhas):
        linha = []
        for coluna in range(qt_colunas):
            linha.append(random.randint(1,100))
        matriz.append(linha)

    return(matriz)

matriz=criar_matriz(5,5)

for linha in matriz:
    print(linha)
# Out:
# [9, 38, 74, 36, 86]
# [84, 25, 76, 45, 92]
# [76, 66, 42, 89, 56]
# [93, 65, 29, 100, 13]
# [87, 1, 2, 46, 26]

# %%
for linha in matriz:
    for elemento in linha:
        print(f'{elemento:3d}', end='\t')
    print()
# Out:
#  36	 54	 13
#  80	 72	 49
#  17	 21	 23

# %%
matriz = []
for i in range(4):
    linha = []
    for j in range(4):
        valor = int(input(f"Digite o valor para [{i}][{j}]: "))
        linha.append(valor)
    matriz.append(linha)

for linha in matriz:
    print(linha)
# Out:
# [4, 5, 6, 7]
# [8, 4, 3, 2]
# [5, 4, 8, 7]
# [6, 5, 4, 3]

# %%
# Inicializa uma matriz 4x4 vazia
matriz = []

print("Digite os valores da matriz 4x4:")

# Loop para ler as 4 linhas
for i in range(4):
    linha = []  # Inicializa uma linha vazia
    
    # Loop para ler os 4 elementos de cada linha
    for j in range(4):
        valor = int(input(f"Digite o valor para a posição [{i}][{j}]: "))
        linha.append(valor)  # Adiciona o valor à linha
    
    matriz.append(linha)  # Adiciona a linha à matriz

# Exibe a matriz formatada
print("\nMatriz 4x4:")
for linha in matriz:
    for elemento in linha:
        print(f"{elemento:4d}", end=" ")  # Formata cada elemento com 4 espaços
    print()  # Pula linha após cada linha da matriz
# Out:
# Digite os valores da matriz 4x4:
#
# Matriz 4x4:
#    7    7    7    7
#    7    7    7  415
#   84   84   45   85
#   96   98   78   98

# %%
def imprime_matriz(matriz=[]): 

    for linha in matriz:
        for elemento in linha:
            print(f"{elemento:4d}", end=" ")  # Formata cada elemento com 4 espaços
        print()  # Pula linha após cada linha da matriz

# %%
minha_matriz = criar_matriz
imprime_matriz = minha_matriz(6,7)

# %%
imprime_matriz(minha_matriz)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[48], line 1
# ----> 1 imprime_matriz(minha_matriz)
#
# TypeError: 'list' object is not callable

# %%
def imprime_matriz_v2(matriz=[]):
    if isinstance(matriz,list):    
        for linha in matriz: 
            if isinstance(linha, list):
                for elemento in linha :
                    print(f"{elemento:4d}",end=" ")
                print()

# %% [markdown]
# #### Maior Valor da Linha

# %%
linha_atual=1
for linha in minha_matriz :
    #print(max(linha))
    print(f"O maior valor da {linha_atual}a. é {max(linha)}")
    linha_atual+=1
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[50], line 2
#       1 linha_atual=1
# ----> 2 for linha in minha_matriz :
#       3     #print(max(linha))
#       4     print(f"O maior valor da {linha_atual}a. é {max(linha)}")
#       5     linha_atual+=1
#
# TypeError: 'function' object is not iterable

# %% [markdown]
# #### Soma dos Elementos da Diagonal Principal

# %%
import random

matriz = []

for i in range(4):
    linha = []
    for j in range(4):
        linha.append(random.randint(1,100))
    matriz.append(linha)
