# %% [markdown]
# # Listas - Tuplas e Ranges

# %%
tupla=(1,2)
type(tupla)

# %%
lista=[1,2]
type=lista

# %%
lista.append(3)
lista.append(6)
lista.append(35)
lista.append(45)

# %%
print(lista)

# %%
print(tupla[1])

# %%
list=list(range(1,10))
print(list)

# %%
nome=input("Digite seu nome")
idade=input("Digite o ano do seu nascimento")

# %%
idade_int=int(idade)

# %%
idade1=2026 - (idade_int)

# %%
if idade1 > 18: print(f'{nome}, Você possui {idade1} anos. Portanto, você é maior de idade.')
elif idade1 > 16: print(f'{nome}, Você possui {idade1}. Portanto você é adolescente de idade.')
else: print(f'{nome}, Você possui {idade1} anos. Portanto, você não é maior de idade.')
# Out:
# Carlos, Você possui 17. Portanto você é adolescente de idade.
