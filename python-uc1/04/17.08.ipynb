# %%
inteiro=10
ponto_flutuante=3.14
numero_complexo=2+3j

# %%
print(type(inteiro))
# Out:
# <class 'int'>

# %%
print(type(ponto_flutuante))
# Out:
# <class 'float'>

# %%
print(type(numero_complexo))
# Out:
# <class 'complex'>

# %% [markdown]
# # Testando as Strings

# %%
nome="Carlos"

# %%
cep="25750000"

# %%
Logradouro="""Estrada União e Indústria, 21222
Bairro: Pedro do Rio
Cidade: Petrópolis
Estado: RJ"""

# %%
print(Logradouro)
# Out:
# Estrada União e Indústria, 21222
# Bairro: Pedro do Rio
# Cidade: Petrópolis
# Estado: RJ

# %% [markdown]
# # Variáves Booleanas

# %%
numero1=5
numero2=7

# %%
resultado=numero1 > numero2

# %%
resultado2=numero1 < numero2

# %%
print(resultado)
# Out:
# False

# %%
print(resultado2)
# Out:
# True
