# %%
nome=input("Digite o seu nome")

# %%
ano_nascimento=input("Digite o ano do seu nascimento")

# %%
nome_int=str(nome)

# %%
ano_nascimento_int=int(ano_nascimento)
idade=(2026 - (ano_nascimento_int))

# %%
print(f"{nome} sua idade aproximada é {idade}")
# Out:
# Carlos sua idade aproximada é 22
